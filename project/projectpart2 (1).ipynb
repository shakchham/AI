# %% [markdown]
# #EDA

# %% [markdown]
# ##Profiling

# %% [markdown]
# ###Head, Info , Describe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ### Duplicated and null check

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Histogram

# %%
print(df['Class'].value_counts())
sns.countplot(x='Class', data=df)
plt.title('Class Distribution (0: Non-Fraud, 1: Fraud)')
plt.show()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ### Correlataion

# %%
plt.figure(figsize=(15,12))
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm_r', annot=False, center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
df_copy = df.copy()

# %%
df_copy.dropna(inplace=True)

# %%
df_copy = df_copy.drop_duplicates()

# %%
df_copy.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ### Histogram

# %%
sns.countplot(data=df_copy, x='Class')
plt.title("Class Distribution")
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])
plt.show()

# %%
plt.figure(figsize=(12, 10))
corr = df_copy.corr()
sns.heatmap(corr, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Boxplot to remove outliners

# %%
sns.boxplot(data=df_copy, x='Class', y='V17')
plt.title("V17 vs Class")
plt.show()

sns.boxplot(data=df_copy, x='Class', y='V14')
plt.title("V14 vs Class")
plt.show()

# %% [markdown]
# #### using IQR to remove outliners

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
columns_to_check = ['V14', 'V17']

for col in columns_to_check:
    Q1 = df_copy[col].quantile(0.25)
    Q3 = df_copy[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_copy = df_copy[(df_copy[col] >= lower_bound) & (df_copy[col] <= upper_bound)]

# %%
sns.boxplot(data=df_copy, x='Class', y='V17')
plt.title("V17 vs Class")
plt.show()

sns.boxplot(data=df_copy, x='Class', y='V14')
plt.title("V14 vs Class")
plt.show()

# %% [markdown]
# #Modeling

# %%
# ───────────── Simple Modeling (Baseline) ─────────────

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, roc_auc_score

# ─────────────────────────────────────────────
# 🔹 1. Data Preparation
X = df_copy.drop(columns=['Class'])
y = df_copy['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ─────────────────────────────────────────────
# 🔹 2. Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ─────────────────────────────────────────────
# 🔹 3. Logistic Regression
log_reg = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
log_reg.fit(X_train_scaled, y_train)

y_pred_log = log_reg.predict(X_test_scaled)
y_proba_log = log_reg.predict_proba(X_test_scaled)[:, 1]

print("\n🔹 Logistic Regression")
print(classification_report(y_test, y_pred_log))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba_log))

# ─────────────────────────────────────────────
# 🔹 4. Decision Tree Classifier
tree_clf = DecisionTreeClassifier(max_depth=5, class_weight='balanced', random_state=42)
tree_clf.fit(X_train, y_train)

y_pred_tree = tree_clf.predict(X_test)
y_proba_tree = tree_clf.predict_proba(X_test)[:, 1]

print("\n🔹 Decision Tree")
print(classification_report(y_test, y_pred_tree))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba_tree))

# ─────────────────────────────────────────────
# 🔹 5. Predict New Sample
expected_features = X.shape[1]
new_data = [[0.1] * expected_features]  # Replace with real input values

if len(new_data[0]) != expected_features:
    raise ValueError(f"❌ new_data must have {expected_features} features.")

new_data_scaled = scaler.transform(new_data)
log_pred = log_reg.predict(new_data_scaled)
print("Predicted (LogReg):", log_pred[0])
# Out:
# 🔹 Logistic Regression
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     52365
#            1       0.00      0.62      0.00         8
#
#     accuracy                           0.85     52373
#    macro avg       0.50      0.74      0.46     52373
# weighted avg       1.00      0.85      0.92     52373
#
# ROC AUC Score: 0.7999450969158789
#
# 🔹 Decision Tree
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     52365
#            1       0.00      0.38      0.00         8
#
#     accuracy                           0.91     52373
#    macro avg       0.50      0.64      0.48     52373
# weighted avg       1.00      0.91      0.95     52373
#
# ROC AUC Score: 0.6455385276425093
# Predicted (LogReg): 0
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
# ...

# %%
### Tuning

# %% [markdown]
# ##Tuning

# %%
# ───────────── Tuned Logistic Regression with RandomizedSearchCV ─────────────

import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score
from scipy.stats import loguniform
import numpy as np

# ─────────────────────────────────────────────
# 🔹 1. Data Preparation
X = df_copy.drop(columns=['Class'])
y = df_copy['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ─────────────────────────────────────────────
# 🔹 2. Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ─────────────────────────────────────────────
# 🔹 3. Define Randomized Search Parameters
param_dist = {
    'C': loguniform(0.01, 10),  # Continuous distribution over [0.01, 10]
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']  # Supports both 'l1' and 'l2'
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
log_reg = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)

random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=20,          # Number of parameter settings to sample
    scoring='roc_auc',
    cv=cv,
    n_jobs=-1,
    verbose=1,
    random_state=42
)

# ─────────────────────────────────────────────
# 🔹 4. Fit RandomizedSearchCV
random_search.fit(X_train_scaled, y_train)
best_model = random_search.best_estimator_

# ─────────────────────────────────────────────
# 🔹 5. Evaluation on Test Set
y_pred = best_model.predict(X_test_scaled)
y_proba = best_model.predict_proba(X_test_scaled)[:, 1]

print("\n🔹 Best Logistic Regression Parameters:", random_search.best_params_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# ─────────────────────────────────────────────
# 🔹 6. Optional Threshold Tuning
threshold = 0.3
y_pred_thresh = (y_proba >= threshold).astype(int)

print(f"\n🔹 Logistic Regression (Threshold = {threshold})")
print(classification_report(y_test, y_pred_thresh))

# ─────────────────────────────────────────────
# 🔹 7. Predict New Sample
expected_features = X.shape[1]
new_data = [[0.1] * expected_features]  # Replace with actual values

if len(new_data[0]) != expected_features:
    raise ValueError(f"❌ new_data must have {expected_features} features.")

new_data_scaled = scaler.transform(new_data)
new_pred = best_model.predict(new_data_scaled)
print("Predicted Class:", new_pred[0])
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-1138094765> in <cell line: 0>()
#      48 # ─────────────────────────────────────────────
#      49 # 🔹 4. Fit RandomizedSearchCV
# ---> 50 random_search.fit(X_train_scaled, y_train)
#      51 best_model = random_search.best_estimator_
#      52
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
# ...

# %%
import joblib

joblib.dump((model, scaler, le), "base.pkl")
joblib.dump((best_model, scaler, le), "fine.pkl")

# %% [markdown]
# ##Findings

# %% [markdown]
# 1. The model is 85% accurate using Logistic Regression and 91% accuracy using Decision Tree
# 2. Logistic Regression achieved a ROC AUC score of ~0.80, indicating it can    better distinguish between classes overall.
# 3.Decision Tree showed higher overall accuracy (91%) compared to Logistic Regression (85%), but this is largely due to correctly classifying the majority class.
# 4. Imbalanced Dataset Challenge:
# 5. Baseline Model and Tuned model gave similar amount of accuracy.
